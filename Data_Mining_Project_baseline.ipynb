# %% [markdown]
# # Therapy Recommadation Systems for Patients
# - University of Trento
# - Data Mining
# - Ali Akay
# - MSc. Artificial Intelligence Systems

# %%
import io, json
import pandas as pd
import numpy as np
from sklearn.neighbors import NearestNeighbors
from sklearn import preprocessing
from sklearn.model_selection import train_test_split as sklearn_train_test_split
from sklearn.preprocessing import LabelEncoder
from scipy.sparse import csr_matrix
from math import sqrt
from sklearn.metrics import mean_squared_error

# %%
f = open('Dataset/datasetB.json', 'r')
dataset = json.loads(f.read())
dataset
# Out:
# {'Conditions': [{'id': 'Cond1',
#    'name': 'Abdominal aortic aneurysm',
#    'type': 'Blood Diseases'},
#   {'id': 'Cond2', 'name': 'Acne', 'type': 'Newborn Screening'},
#   {'id': 'Cond3',
#    'name': 'Acute cholecystitis',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond4',
#    'name': 'Acute lymphoblastic leukaemia',
#    'type': 'Lung Diseases'},
#   {'id': 'Cond5',
#    'name': 'Acute lymphoblastic leukaemia: Children',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond6',
#    'name': 'Acute lymphoblastic leukaemia: Teenagers and young adults',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond7',
#    'name': 'Acute myeloid leukaemia',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond8',
#    'name': 'Acute myeloid leukaemia: Children',
#    'type': 'Blood Diseases'},
#   {'id': 'Cond9',
#    'name': 'Acute myeloid leukaemia: Teenagers and young adults',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond10', 'name': 'Acute pancreatitis', 'type': 'Rare Cancers'},
#   {'id': 'Cond11',
#    'name': "Addison's disease",
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond12',
#    'name': 'Alcohol-related liver disease',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond13', 'name': 'Allergic rhinitis', 'type': 'Viral infections'},
#   {'id': 'Cond14',
#    'name': 'Allergies',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond15', 'name': "Alzheimer's disease", 'type': 'Skin Diseases'},
#   {'id': 'Cond16',
#    'name': 'Anal cancer',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond17',
#    'name': 'Anaphylaxis',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond18', 'name': 'Angioedema', 'type': 'Digestive Diseases'},
#   {'id': 'Cond19', 'name': 'Ankylosing spondylitis', 'type': 'Lung Diseases'},
#   {'id': 'Cond20', 'name': 'Anorexia nervosa', 'type': 'Metabolic disorders'},
#   {'id': 'Cond21', 'name': 'Anxiety', 'type': 'Lung Diseases'},
#   {'id': 'Cond22',
#    'name': 'Anxiety disorders in children',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond23', 'name': 'Appendicitis', 'type': 'Rare Cancers'},
#   {'id': 'Cond24', 'name': 'Arthritis', 'type': 'Musculoskeletal Diseases'},
#   {'id': 'Cond25', 'name': 'Asbestosis', 'type': 'Musculoskeletal Diseases'},
#   {'id': 'Cond26', 'name': 'Asthma', 'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond27', 'name': 'Atopic eczema', 'type': 'Endocrine Diseases'},
#   {'id': 'Cond28',
#    'name': 'Attention deficit hyperactivity disorder (ADHD)',
#    'type': 'Immune System Diseases'},
#   {'id': 'Cond29',
#    'name': 'Autistic spectrum disorder (ASD)',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond30',
#    'name': 'Bacterial vaginosis',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond31',
#    'name': 'Benign prostate enlargement',
#    'type': 'Skin Diseases'},
#   {'id': 'Cond32',
#    'name': 'Bile duct cancer (cholangiocarcinoma)',
#    'type': 'Rare Cancers'},
#   {'id': 'Cond33',
#    'name': 'Binge eating',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond34',
#    'name': 'Bipolar disorder',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond35',
#    'name': 'Bladder cancer',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond36',
#    'name': 'Blood poisoning (sepsis)',
#    'type': 'Viral infections'},
#   {'id': 'Cond37',
#    'name': 'Bone cancer',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond38',
#    'name': 'Bone cancer: Teenagers and young adults',
#    'type': 'Endocrine Diseases'},
#   {'id': 'Cond39', 'name': 'Bowel cancer', 'type': 'Eye diseases'},
#   {'id': 'Cond40',
#    'name': 'Bowel incontinence',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond41', 'name': 'Bowel polyps', 'type': 'Environmental Diseases'},
#   {'id': 'Cond42',
#    'name': 'Brain stem death',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond43', 'name': 'Brain tumours', 'type': 'Chromosome Disorders'},
#   {'id': 'Cond44',
#    'name': 'Brain tumours: Children',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond45',
#    'name': 'Brain tumours: Teenagers and young adults',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond46',
#    'name': 'Breast cancer (female)',
#    'type': 'Viral infections'},
#   {'id': 'Cond47',
#    'name': 'Breast cancer (male)',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond48',
#    'name': 'Bronchiectasis',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond49',
#    'name': 'Bronchitis',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond50', 'name': 'Bulimia', 'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond51', 'name': 'Bunion', 'type': 'Metabolic disorders'},
#   {'id': 'Cond52',
#    'name': 'Carcinoid syndrome and carcinoid tumours',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond53',
#    'name': 'Catarrh',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond54', 'name': 'Cellulitis', 'type': 'Newborn Screening'},
#   {'id': 'Cond55',
#    'name': 'Cervical cancer',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond56', 'name': 'Chest infection', 'type': 'Bacterial infections'},
#   {'id': 'Cond57', 'name': 'Chest pain', 'type': 'Heart Diseases'},
#   {'id': 'Cond58', 'name': 'Chickenpox', 'type': 'Nervous System Diseases'},
#   {'id': 'Cond59', 'name': 'Chilblains', 'type': 'Eye diseases'},
#   {'id': 'Cond60', 'name': 'Chlamydia', 'type': 'Rare Cancers'},
#   {'id': 'Cond61', 'name': 'Chronic fatigue syndrome', 'type': 'Rare Cancers'},
#   {'id': 'Cond62',
#    'name': 'Chronic kidney disease',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond63',
#    'name': 'Chronic lymphocytic leukaemia',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond64',
#    'name': 'Chronic myeloid leukaemia',
#    'type': 'Fungal infections'},
#   {'id': 'Cond65',
#    'name': 'Chronic obstructive pulmonary disease',
#    'type': 'Fungal infections'},
#   {'id': 'Cond66',
#    'name': 'Chronic pancreatitis',
#    'type': 'Fungal infections'},
#   {'id': 'Cond67', 'name': 'Cirrhosis', 'type': 'Digestive Diseases'},
#   {'id': 'Cond68',
#    'name': 'Clostridium difficile',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond69',
#    'name': 'Coeliac disease',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond70', 'name': 'Cold sore', 'type': 'Eye diseases'},
#   {'id': 'Cond71', 'name': 'Coma', 'type': 'Mouth Diseases'},
#   {'id': 'Cond72', 'name': 'Common cold', 'type': 'Environmental Diseases'},
#   {'id': 'Cond73',
#    'name': 'Common heart conditions',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond74',
#    'name': 'Congenital heart disease',
#    'type': 'Bacterial infections'},
#   {'id': 'Cond75',
#    'name': 'Conjunctivitis',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond76',
#    'name': 'Constipation',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond77',
#    'name': 'Coronavirus (COVID-19)',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond78', 'name': 'Cough', 'type': 'Digestive Diseases'},
#   {'id': 'Cond79',
#    'name': "Crohn's disease",
#    'type': 'Immune System Diseases'},
#   {'id': 'Cond80', 'name': 'Croup', 'type': 'Newborn Screening'},
#   {'id': 'Cond81', 'name': 'Cystic fibrosis', 'type': 'Parasitic diseases'},
#   {'id': 'Cond82', 'name': 'Cystitis', 'type': 'Environmental Diseases'},
#   {'id': 'Cond83',
#    'name': 'Deafblindness',
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond84',
#    'name': 'Deep vein thrombosis',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond85', 'name': 'Dehydration', 'type': 'Mouth Diseases'},
#   {'id': 'Cond86', 'name': 'Dementia', 'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond87',
#    'name': 'Dementia with Lewy bodies',
#    'type': 'Newborn Screening'},
#   {'id': 'Cond88', 'name': 'Dental abscess', 'type': 'Viral infections'},
#   {'id': 'Cond89',
#    'name': 'Depression',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond90',
#    'name': 'Dermatitis herpetiformis',
#    'type': 'Skin Diseases'},
#   {'id': 'Cond91', 'name': 'Diabetes', 'type': 'Nervous System Diseases'},
#   {'id': 'Cond92', 'name': 'Diarrhoea', 'type': 'Mouth Diseases'},
#   {'id': 'Cond93', 'name': 'Discoid eczema', 'type': 'Nutritional diseases'},
#   {'id': 'Cond94',
#    'name': 'Diverticular disease and diverticulitis',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond95',
#    'name': 'Dizziness (Lightheadedness)',
#    'type': 'Lung Diseases'},
#   {'id': 'Cond96',
#    'name': "Down's syndrome",
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond97',
#    'name': 'Dry mouth',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond98',
#    'name': 'Dysphagia (swallowing problems)',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond99', 'name': 'Dystonia', 'type': 'Skin Diseases'},
#   {'id': 'Cond100', 'name': 'Earache', 'type': 'Lung Diseases'},
#   {'id': 'Cond101',
#    'name': 'Earwax build-up',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond102',
#    'name': 'Ebola virus disease',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond103', 'name': 'Ectopic pregnancy', 'type': 'Viral infections'},
#   {'id': 'Cond104', 'name': 'Endometriosis', 'type': 'Environmental Diseases'},
#   {'id': 'Cond105',
#    'name': 'Epilepsy',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond106',
#    'name': 'Erectile dysfunction (impotence)',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond107',
#    'name': 'Escherichia coli (E. coli) O157',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond108',
#    'name': 'Ewing sarcoma',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond109',
#    'name': 'Ewing sarcoma: Children',
#    'type': 'Newborn Screening'},
#   {'id': 'Cond110',
#    'name': 'Eye cancer',
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond111',
#    'name': 'Febrile seizures',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond112',
#    'name': 'Fever in adults',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond113', 'name': 'Fever in children', 'type': 'Rare Cancers'},
#   {'id': 'Cond114', 'name': 'Fibroids', 'type': 'Eye diseases'},
#   {'id': 'Cond115', 'name': 'Fibromyalgia', 'type': 'Eye diseases'},
#   {'id': 'Cond116',
#    'name': 'Flatulence',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond117', 'name': 'Flu', 'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond118',
#    'name': 'Foetal alcohol syndrome',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond119',
#    'name': 'Food poisoning',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond120',
#    'name': 'Fungal nail infection',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond121',
#    'name': 'Gallbladder cancer',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond122', 'name': 'Gallstones', 'type': 'Environmental Diseases'},
#   {'id': 'Cond123',
#    'name': 'Ganglion cyst',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond124',
#    'name': 'Gastroenteritis',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond125',
#    'name': 'Gastro-oesophageal reflux disease (GORD)',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond126', 'name': 'Genital herpes', 'type': 'Viral infections'},
#   {'id': 'Cond127', 'name': 'Genital warts', 'type': 'Mouth Diseases'},
#   {'id': 'Cond128',
#    'name': 'Germ cell tumours',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond129', 'name': 'Glandular fever', 'type': 'Nutritional diseases'},
#   {'id': 'Cond130',
#    'name': 'Gonorrhoea',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond131', 'name': 'Gout', 'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond132',
#    'name': 'Gum disease',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond133',
#    'name': 'Haemorrhoids (piles)',
#    'type': 'Immune System Diseases'},
#   {'id': 'Cond134',
#    'name': 'Hairy cell leukaemia',
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond135',
#    'name': 'Hand, foot and mouth disease',
#    'type': 'Immune System Diseases'},
#   {'id': 'Cond136', 'name': 'Hay fever', 'type': 'Heart Diseases'},
#   {'id': 'Cond137',
#    'name': 'Head and neck cancer',
#    'type': 'Digestive Diseases'},
#   {'id': 'Cond138', 'name': 'Head lice and nits', 'type': 'Mouth Diseases'},
#   {'id': 'Cond139', 'name': 'Headaches', 'type': 'Metabolic disorders'},
#   {'id': 'Cond140',
#    'name': 'Hearing loss',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond141',
#    'name': 'Heart failure',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond142', 'name': 'Hepatitis A', 'type': 'Digestive Diseases'},
#   {'id': 'Cond143', 'name': 'Hepatitis B', 'type': 'Nervous System Diseases'},
#   {'id': 'Cond144', 'name': 'Hepatitis C', 'type': 'Eye diseases'},
#   {'id': 'Cond145', 'name': 'Hiatus hernia', 'type': 'Heart Diseases'},
#   {'id': 'Cond146', 'name': 'High cholesterol', 'type': 'Viral infections'},
#   {'id': 'Cond147', 'name': 'HIV', 'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond148', 'name': 'Hodgkin lymphoma', 'type': 'Rare Cancers'},
#   {'id': 'Cond149',
#    'name': 'Hodgkin lymphoma: Children',
#    'type': 'Bacterial infections'},
#   {'id': 'Cond150',
#    'name': 'Hodgkin lymphoma: Teenagers and young adults',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond151',
#    'name': "Huntington's disease",
#    'type': 'Endocrine Diseases'},
#   {'id': 'Cond152',
#    'name': 'Hyperglycaemia (high blood sugar)',
#    'type': 'Lung Diseases'},
#   {'id': 'Cond153',
#    'name': 'Hyperhidrosis',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond154',
#    'name': 'Hypoglycaemia (low blood sugar)',
#    'type': 'Chromosome Disorders'},
#   {'id': 'Cond155',
#    'name': 'Idiopathic pulmonary fibrosis',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond156', 'name': 'Impetigo', 'type': 'Metabolic disorders'},
#   {'id': 'Cond157',
#    'name': 'Indigestion',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond158', 'name': 'Ingrown toenail', 'type': 'Digestive Diseases'},
#   {'id': 'Cond159',
#    'name': 'Inherited heart conditions',
#    'type': 'Rare Cancers'},
#   {'id': 'Cond160',
#    'name': 'Insomnia',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond161',
#    'name': 'Iron deficiency anaemia',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond162',
#    'name': 'Irritable bowel syndrome (IBS)',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond163',
#    'name': 'Irritable hip',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond164', 'name': 'Itching', 'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond165', 'name': 'Itchy bottom', 'type': 'Eye diseases'},
#   {'id': 'Cond166',
#    'name': "Kaposi's sarcoma",
#    'type': 'Immune System Diseases'},
#   {'id': 'Cond167', 'name': 'Kidney cancer', 'type': 'Environmental Diseases'},
#   {'id': 'Cond168',
#    'name': 'Kidney infection',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond169',
#    'name': 'Kidney stones',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond170', 'name': 'Labyrinthitis', 'type': 'Blood Diseases'},
#   {'id': 'Cond171',
#    'name': 'Lactose intolerance',
#    'type': 'Bacterial infections'},
#   {'id': 'Cond172',
#    'name': 'Langerhans cell histiocytosis',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond173',
#    'name': 'Laryngeal (larynx) cancer',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond174', 'name': 'Laryngitis', 'type': 'Parasitic diseases'},
#   {'id': 'Cond175', 'name': 'Leg cramps', 'type': 'Metabolic disorders'},
#   {'id': 'Cond176', 'name': 'Lichen planus', 'type': 'Viral infections'},
#   {'id': 'Cond177', 'name': 'Liver cancer', 'type': 'Nutritional diseases'},
#   {'id': 'Cond178',
#    'name': 'Liver disease',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond179',
#    'name': 'Liver tumours',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond180', 'name': 'Loss of libido', 'type': 'Heart Diseases'},
#   {'id': 'Cond181', 'name': 'Lung cancer', 'type': 'Chromosome Disorders'},
#   {'id': 'Cond182', 'name': 'Lupus', 'type': 'Skin Diseases'},
#   {'id': 'Cond183',
#    'name': 'Lyme disease',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond184', 'name': 'Lymphoedema', 'type': 'Skin Diseases'},
#   {'id': 'Cond185',
#    'name': 'Lymphogranuloma venereum (LGV)',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond186', 'name': 'Malaria', 'type': 'Mouth Diseases'},
#   {'id': 'Cond187',
#    'name': 'Malignant brain tumour (cancerous)',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond188',
#    'name': 'Malnutrition',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond189', 'name': 'Measles', 'type': 'Parasitic diseases'},
#   {'id': 'Cond190', 'name': 'Meningitis', 'type': 'Heart Diseases'},
#   {'id': 'Cond191', 'name': 'Menopause', 'type': 'Rare Cancers'},
#   {'id': 'Cond192', 'name': 'Mesothelioma', 'type': 'Mouth Diseases'},
#   {'id': 'Cond193',
#    'name': 'Middle ear infection (otitis media)',
#    'type': 'Mouth Diseases'},
#   {'id': 'Cond194', 'name': 'Migraine', 'type': 'Bacterial infections'},
#   {'id': 'Cond195', 'name': 'Miscarriage', 'type': 'Viral infections'},
#   {'id': 'Cond196',
#    'name': 'Motor neurone disease (MND)',
#    'type': 'Endocrine Diseases'},
#   {'id': 'Cond197', 'name': 'Mouth cancer', 'type': 'Nervous System Diseases'},
#   {'id': 'Cond198', 'name': 'Mouth ulcer', 'type': 'Blood Diseases'},
#   {'id': 'Cond199', 'name': 'Multiple myeloma', 'type': 'Rare Cancers'},
#   {'id': 'Cond200',
#    'name': 'Multiple sclerosis (MS)',
#    'type': 'Bacterial infections'},
#   {'id': 'Cond201', 'name': 'Mumps', 'type': 'Parasitic diseases'},
#   {'id': 'Cond202',
#    'name': "Meniere's disease",
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond203', 'name': 'Nasal and sinus cancer', 'type': 'Rare Cancers'},
#   {'id': 'Cond204',
#    'name': 'Nasopharyngeal cancer',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond205', 'name': 'Neuroblastoma', 'type': 'Viral infections'},
#   {'id': 'Cond206',
#    'name': 'Neuroblastoma: Children',
#    'type': 'Bacterial infections'},
#   {'id': 'Cond207',
#    'name': 'Neuroendocrine tumours',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond208',
#    'name': 'Non-alcoholic fatty liver disease (NAFLD)',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond209',
#    'name': 'Non-Hodgkin lymphoma',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond210',
#    'name': 'Non-Hodgkin lymphoma: Children',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond211', 'name': 'Norovirus', 'type': 'Rare Cancers'},
#   {'id': 'Cond212',
#    'name': 'Nosebleed',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond213', 'name': 'Obesity', 'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond214',
#    'name': 'Obsessive compulsive disorder (OCD)',
#    'type': 'Mouth Diseases'},
#   {'id': 'Cond215',
#    'name': 'Obstructive sleep apnoea',
#    'type': 'Rare Cancers'},
#   {'id': 'Cond216',
#    'name': 'Oesophageal cancer',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond217',
#    'name': 'Oral thrush in adults',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond218',
#    'name': 'Osteoarthritis',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond219', 'name': 'Osteoporosis', 'type': 'Metabolic disorders'},
#   {'id': 'Cond220',
#    'name': 'Osteosarcoma',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond221',
#    'name': 'Otitis externa',
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond222', 'name': 'Ovarian cancer', 'type': 'Parasitic diseases'},
#   {'id': 'Cond223',
#    'name': 'Ovarian cancer: Teenagers and young adults',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond224', 'name': 'Ovarian cyst', 'type': 'Mouth Diseases'},
#   {'id': 'Cond225',
#    'name': 'Overactive thyroid',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond226',
#    'name': "Paget's disease of the nipple",
#    'type': 'Skin Diseases'},
#   {'id': 'Cond227', 'name': 'Pancreatic cancer', 'type': 'Parasitic diseases'},
#   {'id': 'Cond228', 'name': 'Panic disorder', 'type': 'Heart Diseases'},
#   {'id': 'Cond229',
#    'name': "Parkinson's disease",
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond230',
#    'name': 'Pelvic inflammatory disease',
#    'type': 'Chromosome Disorders'},
#   {'id': 'Cond231',
#    'name': 'Pelvic organ prolapse',
#    'type': 'Fungal infections'},
#   {'id': 'Cond232',
#    'name': 'Penile cancer',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond233',
#    'name': 'Peripheral neuropathy',
#    'type': 'Fungal infections'},
#   {'id': 'Cond234', 'name': 'Personality disorder', 'type': 'Skin Diseases'},
#   {'id': 'Cond235', 'name': 'Pleurisy', 'type': 'Environmental Diseases'},
#   {'id': 'Cond236', 'name': 'Pneumonia', 'type': 'Lung Diseases'},
#   {'id': 'Cond237',
#    'name': 'Polymyalgia rheumatica',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond238',
#    'name': 'Post-traumatic stress disorder (PTSD)',
#    'type': 'Chromosome Disorders'},
#   {'id': 'Cond239',
#    'name': 'Postnatal depression',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond240',
#    'name': 'Pregnancy and baby',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond241',
#    'name': 'Pressure ulcers',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond242', 'name': 'Prostate cancer', 'type': 'Chromosome Disorders'},
#   {'id': 'Cond243',
#    'name': 'Psoriasis',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond244',
#    'name': 'Psoriatic arthritis',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond245', 'name': 'Psychosis', 'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond246', 'name': 'Pubic lice', 'type': 'Viral infections'},
#   {'id': 'Cond247',
#    'name': 'Rare tumours',
#    'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond248', 'name': "Raynaud's phenomenon", 'type': 'Skin Diseases'},
#   {'id': 'Cond249',
#    'name': 'Reactive arthritis',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond250',
#    'name': 'Restless legs syndrome',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond251', 'name': 'Retinoblastoma', 'type': 'Skin Diseases'},
#   {'id': 'Cond252',
#    'name': 'Retinoblastoma: Children',
#    'type': 'Heart Diseases'},
#   {'id': 'Cond253', 'name': 'Rhabdomyosarcoma', 'type': 'Lung Diseases'},
#   {'id': 'Cond254',
#    'name': 'Rheumatoid arthritis',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond255',
#    'name': 'Ringworm and other fungal infections',
#    'type': 'Blood Diseases'},
#   {'id': 'Cond256', 'name': 'Rosacea', 'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond257', 'name': 'Scabies', 'type': 'Blood Diseases'},
#   {'id': 'Cond258', 'name': 'Scarlet fever', 'type': 'Bacterial infections'},
#   {'id': 'Cond259', 'name': 'Schizophrenia', 'type': 'Digestive Diseases'},
#   {'id': 'Cond260',
#    'name': 'Scoliosis',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond261', 'name': 'Septic shock', 'type': 'Blood Diseases'},
#   {'id': 'Cond262',
#    'name': 'Shingles',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond263',
#    'name': 'Shortness of breath',
#    'type': 'Musculoskeletal Diseases'},
#   {'id': 'Cond264',
#    'name': 'Sickle cell disease',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond265', 'name': 'Sinusitis', 'type': 'Parasitic diseases'},
#   {'id': 'Cond266',
#    'name': "Sjogren's syndrome",
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond267',
#    'name': 'Skin cancer (melanoma)',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond268',
#    'name': 'Skin cancer (non-melanoma)',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond269',
#    'name': 'Slapped cheek syndrome',
#    'type': 'Endocrine Diseases'},
#   {'id': 'Cond270',
#    'name': 'Soft tissue sarcomas',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond271',
#    'name': 'Soft tissue sarcomas: Teenagers and young adults',
#    'type': 'Blood Diseases'},
#   {'id': 'Cond272', 'name': 'Sore throat', 'type': 'Nervous System Diseases'},
#   {'id': 'Cond273',
#    'name': 'Spleen problems and spleen removal',
#    'type': 'Environmental Diseases'},
#   {'id': 'Cond274', 'name': 'Stillbirth', 'type': 'Viral infections'},
#   {'id': 'Cond275',
#    'name': 'Stomach ache and abdominal pain',
#    'type': 'Eye diseases'},
#   {'id': 'Cond276', 'name': 'Stomach cancer', 'type': 'Lung Diseases'},
#   {'id': 'Cond277', 'name': 'Stomach ulcer', 'type': 'Skin Diseases'},
#   {'id': 'Cond278',
#    'name': 'Stress, anxiety and low mood',
#    'type': 'Viral infections'},
#   {'id': 'Cond279', 'name': 'Stroke', 'type': 'Male Reproductive Diseases'},
#   {'id': 'Cond280',
#    'name': 'Sudden infant death syndrome (SIDS)',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond281', 'name': 'Suicide', 'type': 'Lung Diseases'},
#   {'id': 'Cond282', 'name': 'Sunburn', 'type': 'Bacterial infections'},
#   {'id': 'Cond283', 'name': 'Swollen glands', 'type': 'Rare Cancers'},
#   {'id': 'Cond284', 'name': 'Syphilis', 'type': 'Newborn Screening'},
#   {'id': 'Cond285', 'name': 'Testicular cancer', 'type': 'Skin Diseases'},
#   {'id': 'Cond286',
#    'name': 'Testicular cancer: Teenagers and young adults',
#    'type': 'Congenital and Genetic Diseases'},
#   {'id': 'Cond287',
#    'name': 'Testicular lumps and swellings',
#    'type': 'Nervous System Diseases'},
#   {'id': 'Cond288', 'name': 'Thirst', 'type': 'Chromosome Disorders'},
#   {'id': 'Cond289',
#    'name': 'Threadworms',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond290', 'name': 'Thrush', 'type': 'Mouth Diseases'},
#   {'id': 'Cond291', 'name': 'Thrush in men', 'type': 'Immune System Diseases'},
#   {'id': 'Cond292',
#    'name': 'Thyroid cancer',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond293',
#    'name': 'Thyroid cancer: Teenagers and young adults',
#    'type': 'Viral infections'},
#   {'id': 'Cond294', 'name': 'Tinnitus', 'type': 'Digestive Diseases'},
#   {'id': 'Cond295',
#    'name': 'Tonsillitis',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond296',
#    'name': 'Tooth decay',
#    'type': 'Connective tissue diseases'},
#   {'id': 'Cond297',
#    'name': 'Toothache',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond298',
#    'name': 'Transient ischaemic attack (TIA)',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond299',
#    'name': 'Trigeminal neuralgia',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond300',
#    'name': 'Tuberculosis (TB)',
#    'type': 'Autoimmune / Autoinflammatory diseases'},
#   {'id': 'Cond301',
#    'name': 'Type 1 diabetes',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond302',
#    'name': 'Type 2 diabetes',
#    'type': 'Ear, Nose, and Throat Diseases'},
#   {'id': 'Cond303',
#    'name': 'Trichomonas infection',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond304', 'name': 'Ulcerative colitis', 'type': 'Eye diseases'},
#   {'id': 'Cond305',
#    'name': 'Underactive thyroid',
#    'type': 'Endocrine Diseases'},
#   {'id': 'Cond306', 'name': 'Urinary incontinence', 'type': 'Heart Diseases'},
#   {'id': 'Cond307',
#    'name': 'Urinary tract infection (UTI)',
#    'type': 'Hereditary Cancer Syndromes'},
#   {'id': 'Cond308',
#    'name': 'Urinary tract infection (UTI) in children',
#    'type': 'Metabolic disorders'},
#   {'id': 'Cond309',
#    'name': 'Urticaria (hives)',
#    'type': 'Myelodysplastic Syndromes'},
#   {'id': 'Cond310', 'name': 'Vaginal cancer', 'type': 'Endocrine Diseases'},
#   {'id': 'Cond311',
#    'name': 'Vaginal thrush',
#    'type': 'Female Reproductive Diseases'},
#   {'id': 'Cond312',
#    'name': 'Varicose eczema',
#    'type': 'Kidney and Urinary Diseases'},
#   {'id': 'Cond313',
#    'name': 'Venous leg ulcer',
#    'type': 'Nutritional diseases'},
#   {'id': 'Cond314',
#    'name': 'Vertigo',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond315',
#    'name': 'Vitamin B12 or folate deficiency anaemia',
#    'type': 'Blood Diseases'},
#   {'id': 'Cond316',
#    'name': 'Vomiting in adults',
#    'type': 'Parasitic diseases'},
#   {'id': 'Cond317', 'name': 'Vulval cancer', 'type': 'Heart Diseases'},
#   {'id': 'Cond318',
#    'name': 'Warts and verrucas',
#    'type': 'Behavioral and mental disorders'},
#   {'id': 'Cond319', 'name': 'Whooping cough', 'type': 'Mouth Diseases'},
#   {'id': 'Cond320', 'name': "Wilms' tumour", 'type': 'Heart Diseases'},
#   {'id': 'Cond321',
#    'name': 'Womb (uterus) cancer',
#    'type': 'Newborn Screening'},
#   {'id': 'Cond322', 'name': 'Yellow fever', 'type': 'Mouth Diseases'}],
#  'Patients': [{'age': 57,
#    'birthdate': '19640714',
#    'blood_group': 'O+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '20080609',
#      'id': 'pc1',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond46'},
#     {'cured': 'Null',
#      'diagnosed': '20131212',
#      'id': 'pc2',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond171'},
#     {'cured': '20120404',
#      'diagnosed': '20111218',
#      'id': 'pc3',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond240'},
#     {'cured': '19650727',
#      'diagnosed': '19650601',
#      'id': 'pc4',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond39'},
#     {'cured': '19731019',
#      'diagnosed': '19730915',
#      'id': 'pc5',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond309'},
#     {'cured': 'Null',
#      'diagnosed': '20110619',
#      'id': 'pc6',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond321'},
#     {'cured': 'Null',
#      'diagnosed': '20090207',
#      'id': 'pc7',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond280'}],
#    'country_of_residence': 'Costa Rica',
#    'email': 'robert32@hotmail.com',
#    'gender': 'male',
#    'id': 0,
#    'name': 'Thomas Oswalt',
#    'occupation': 'TEFL teacher',
#    'trials': [{'condition': 'pc3',
#      'end': '20120109',
#      'id': 'tr1',
#      'start': '20111219',
#      'successful': 86,
#      'therapy': 'Th49'},
#     {'condition': 'pc3',
#      'end': '20120217',
#      'id': 'tr2',
#      'start': '20120203',
#      'successful': 10,
#      'therapy': 'Th45'},
#     {'condition': 'pc3',
#      'end': '20120404',
#      'id': 'tr3',
#      'start': '20120330',
#      'successful': 100,
#      'therapy': 'Th45'},
#     {'condition': 'pc4',
#      'end': '19650727',
#      'id': 'tr4',
#      'start': '19650714',
#      'successful': 100,
#      'therapy': 'Th17'},
#     {'condition': 'pc5',
#      'end': '19731019',
#      'id': 'tr5',
#      'start': '19730919',
#      'successful': 100,
#      'therapy': 'Th47'},
#     {'condition': 'pc7',
#      'end': '20090401',
#      'id': 'tr6',
#      'start': '20090331',
#      'successful': 59,
#      'therapy': 'Th19'},
#     {'condition': 'pc7',
#      'end': '20090512',
#      'id': 'tr7',
#      'start': '20090418',
#      'successful': 58,
#      'therapy': 'Th50'},
#     {'condition': 'pc7',
#      'end': '20090806',
#      'id': 'tr8',
#      'start': '20090711',
#      'successful': 30,
#      'therapy': 'Th3'},
#     {'condition': 'pc7',
#      'end': '20091006',
#      'id': 'tr9',
#      'start': '20090928',
#      'successful': 56,
#      'therapy': 'Th29'},
#     {'condition': 'pc7',
#      'end': '20091106',
#      'id': 'tr10',
#      'start': '20091029',
#      'successful': 62,
#      'therapy': 'Th38'}],
#    'type': 'Patient'},
#   {'age': 91,
#    'birthdate': '19300925',
#    'blood_group': 'B+',
#    'conditions': [],
#    'country_of_residence': 'Samoa',
#    'email': 'adriana76@yahoo.com',
#    'gender': 'female',
#    'id': 1,
#    'name': 'Frances Wolfe',
#    'occupation': 'Research scientist (maths)',
#    'trials': [],
#    'type': 'Patient'},
#   {'age': 95,
#    'birthdate': '19261030',
#    'blood_group': 'A-',
#    'conditions': [{'cured': '19971108',
#      'diagnosed': '19970912',
#      'id': 'pc8',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond279'},
#     {'cured': '19310108',
#      'diagnosed': '19301020',
#      'id': 'pc9',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond206'},
#     {'cured': 'Null',
#      'diagnosed': '19911014',
#      'id': 'pc10',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond266'},
#     {'cured': '19740317',
#      'diagnosed': '19731119',
#      'id': 'pc11',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond2'},
#     {'cured': 'Null',
#      'diagnosed': '19750918',
#      'id': 'pc12',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond198'},
#     {'cured': '19980216',
#      'diagnosed': '19971110',
#      'id': 'pc13',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond170'},
#     {'cured': '19320625',
#      'diagnosed': '19320405',
#      'id': 'pc14',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond112'},
#     {'cured': '19291007',
#      'diagnosed': '19290805',
#      'id': 'pc15',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond87'},
#     {'cured': '19410303',
#      'diagnosed': '19401116',
#      'id': 'pc16',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond263'},
#     {'cured': '19451004',
#      'diagnosed': '19450527',
#      'id': 'pc17',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond308'},
#     {'cured': '20011024',
#      'diagnosed': '20010627',
#      'id': 'pc18',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond113'},
#     {'cured': '19810430',
#      'diagnosed': '19810417',
#      'id': 'pc19',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond168'}],
#    'country_of_residence': 'Burkina Faso',
#    'email': 'christopher61@hotmail.com',
#    'gender': 'female',
#    'id': 2,
#    'name': 'Virginia Connolly',
#    'occupation': 'Probation officer',
#    'trials': [{'condition': 'pc8',
#      'end': '19971108',
#      'id': 'tr11',
#      'start': '19971010',
#      'successful': 100,
#      'therapy': 'Th36'},
#     {'condition': 'pc9',
#      'end': '19301107',
#      'id': 'tr12',
#      'start': '19301030',
#      'successful': 8,
#      'therapy': 'Th44'},
#     {'condition': 'pc9',
#      'end': '19310108',
#      'id': 'tr13',
#      'start': '19301219',
#      'successful': 100,
#      'therapy': 'Th23'},
#     {'condition': 'pc11',
#      'end': '19731201',
#      'id': 'tr14',
#      'start': '19731119',
#      'successful': 73,
#      'therapy': 'Th6'},
#     {'condition': 'pc11',
#      'end': '19740116',
#      'id': 'tr15',
#      'start': '19731225',
#      'successful': 64,
#      'therapy': 'Th3'},
#     {'condition': 'pc11',
#      'end': '19740317',
#      'id': 'tr16',
#      'start': '19740129',
#      'successful': 100,
#      'therapy': 'Th23'},
#     {'condition': 'pc13',
#      'end': '19980216',
#      'id': 'tr17',
#      'start': '19971230',
#      'successful': 100,
#      'therapy': 'Th1'},
#     {'condition': 'pc14',
#      'end': '19320518',
#      'id': 'tr18',
#      'start': '19320406',
#      'successful': 8,
#      'therapy': 'Th4'},
#     {'condition': 'pc14',
#      'end': '19320625',
#      'id': 'tr19',
#      'start': '19320610',
#      'successful': 100,
#      'therapy': 'Th4'},
#     {'condition': 'pc15',
#      'end': '19291007',
#      'id': 'tr20',
#      'start': '19290820',
#      'successful': 100,
#      'therapy': 'Th46'},
#     {'condition': 'pc16',
#      'end': '19410205',
#      'id': 'tr21',
#      'start': '19401227',
#      'successful': 17,
#      'therapy': 'Th44'},
#     {'condition': 'pc16',
#      'end': '19410303',
#      'id': 'tr22',
#      'start': '19410211',
#      'successful': 100,
#      'therapy': 'Th26'},
#     {'condition': 'pc17',
#      'end': '19450708',
#      'id': 'tr23',
#      'start': '19450630',
#      'successful': 47,
#      'therapy': 'Th21'},
#     {'condition': 'pc17',
#      'end': '19451004',
#      'id': 'tr24',
#      'start': '19450905',
#      'successful': 100,
#      'therapy': 'Th36'},
#     {'condition': 'pc18',
#      'end': '20010829',
#      'id': 'tr25',
#      'start': '20010821',
#      'successful': 35,
#      'therapy': 'Th20'},
#     {'condition': 'pc18',
#      'end': '20011024',
#      'id': 'tr26',
#      'start': '20010907',
#      'successful': 100,
#      'therapy': 'Th22'},
#     {'condition': 'pc19',
#      'end': '19810430',
#      'id': 'tr27',
#      'start': '19810417',
#      'successful': 100,
#      'therapy': 'Th36'}],
#    'type': 'Patient'},
#   {'age': 49,
#    'birthdate': '19721206',
#    'blood_group': 'AB+',
#    'conditions': [{'cured': '19851224',
#      'diagnosed': '19841218',
#      'id': 'pc20',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond215'},
#     {'cured': '20090618',
#      'diagnosed': '20090415',
#      'id': 'pc21',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond184'},
#     {'cured': 'Null',
#      'diagnosed': '19740708',
#      'id': 'pc22',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond293'}],
#    'country_of_residence': 'Haiti',
#    'email': 'jamesramirez@hotmail.com',
#    'gender': 'male',
#    'id': 3,
#    'name': 'John Box',
#    'occupation': 'Art gallery manager',
#    'trials': [{'condition': 'pc20',
#      'end': '19850130',
#      'id': 'tr28',
#      'start': '19850101',
#      'successful': 10,
#      'therapy': 'Th40'},
#     {'condition': 'pc20',
#      'end': '19850301',
#      'id': 'tr29',
#      'start': '19850226',
#      'successful': 14,
#      'therapy': 'Th12'},
#     {'condition': 'pc20',
#      'end': '19850514',
#      'id': 'tr30',
#      'start': '19850329',
#      'successful': 54,
#      'therapy': 'Th36'},
#     {'condition': 'pc20',
#      'end': '19850823',
#      'id': 'tr31',
#      'start': '19850704',
#      'successful': 73,
#      'therapy': 'Th35'},
#     {'condition': 'pc20',
#      'end': '19851028',
#      'id': 'tr32',
#      'start': '19850916',
#      'successful': 26,
#      'therapy': 'Th24'},
#     {'condition': 'pc20',
#      'end': '19851224',
#      'id': 'tr33',
#      'start': '19851209',
#      'successful': 100,
#      'therapy': 'Th51'},
#     {'condition': 'pc21',
#      'end': '20090618',
#      'id': 'tr34',
#      'start': '20090429',
#      'successful': 100,
#      'therapy': 'Th44'}],
#    'type': 'Patient'},
#   {'age': 67,
#    'birthdate': '19540707',
#    'blood_group': 'AB-',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '20120311',
#      'id': 'pc23',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond246'},
#     {'cured': '19980607',
#      'diagnosed': '19980413',
#      'id': 'pc24',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond1'},
#     {'cured': '19870122',
#      'diagnosed': '19860418',
#      'id': 'pc25',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond191'},
#     {'cured': 'Null',
#      'diagnosed': '19790518',
#      'id': 'pc26',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond133'},
#     {'cured': '19830903',
#      'diagnosed': '19830611',
#      'id': 'pc27',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond61'},
#     {'cured': '19880907',
#      'diagnosed': '19880615',
#      'id': 'pc28',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond111'},
#     {'cured': '20060531',
#      'diagnosed': '20051121',
#      'id': 'pc29',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond121'},
#     {'cured': '19750712',
#      'diagnosed': '19740918',
#      'id': 'pc30',
#      'isCured': True,
#      'isTreated': False,
#      'kind': 'Cond11'},
#     {'cured': '19890621',
#      'diagnosed': '19881121',
#      'id': 'pc31',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond271'}],
#    'country_of_residence': 'Niue',
#    'email': 'steven40@hotmail.com',
#    'gender': 'male',
#    'id': 4,
#    'name': 'Stanley Ramos',
#    'occupation': 'Office manager',
#    'trials': [{'condition': 'pc23',
#      'end': '20120422',
#      'id': 'tr35',
#      'start': '20120415',
#      'successful': 23,
#      'therapy': 'Th14'},
#     {'condition': 'pc23',
#      'end': '20120608',
#      'id': 'tr36',
#      'start': '20120501',
#      'successful': 48,
#      'therapy': 'Th29'},
#     {'condition': 'pc24',
#      'end': '19980607',
#      'id': 'tr37',
#      'start': '19980421',
#      'successful': 100,
#      'therapy': 'Th24'},
#     {'condition': 'pc25',
#      'end': '19860507',
#      'id': 'tr38',
#      'start': '19860422',
#      'successful': 48,
#      'therapy': 'Th3'},
#     {'condition': 'pc25',
#      'end': '19860808',
#      'id': 'tr39',
#      'start': '19860629',
#      'successful': 50,
#      'therapy': 'Th20'},
#     {'condition': 'pc25',
#      'end': '19860901',
#      'id': 'tr40',
#      'start': '19860810',
#      'successful': 67,
#      'therapy': 'Th7'},
#     {'condition': 'pc25',
#      'end': '19861205',
#      'id': 'tr41',
#      'start': '19861019',
#      'successful': 68,
#      'therapy': 'Th15'},
#     {'condition': 'pc25',
#      'end': '19870122',
#      'id': 'tr42',
#      'start': '19870101',
#      'successful': 100,
#      'therapy': 'Th15'},
#     {'condition': 'pc27',
#      'end': '19830716',
#      'id': 'tr43',
#      'start': '19830614',
#      'successful': 55,
#      'therapy': 'Th49'},
#     {'condition': 'pc27',
#      'end': '19830903',
#      'id': 'tr44',
#      'start': '19830725',
#      'successful': 100,
#      'therapy': 'Th14'},
#     {'condition': 'pc28',
#      'end': '19880907',
#      'id': 'tr45',
#      'start': '19880809',
#      'successful': 100,
#      'therapy': 'Th15'},
#     {'condition': 'pc29',
#      'end': '20051220',
#      'id': 'tr46',
#      'start': '20051128',
#      'successful': 80,
#      'therapy': 'Th14'},
#     {'condition': 'pc29',
#      'end': '20060302',
#      'id': 'tr47',
#      'start': '20060212',
#      'successful': 10,
#      'therapy': 'Th2'},
#     {'condition': 'pc29',
#      'end': '20060331',
#      'id': 'tr48',
#      'start': '20060322',
#      'successful': 12,
#      'therapy': 'Th10'},
#     {'condition': 'pc29',
#      'end': '20060531',
#      'id': 'tr49',
#      'start': '20060517',
#      'successful': 100,
#      'therapy': 'Th5'},
#     {'condition': 'pc31',
#      'end': '19890129',
#      'id': 'tr50',
#      'start': '19890107',
#      'successful': 23,
#      'therapy': 'Th10'},
#     {'condition': 'pc31',
#      'end': '19890301',
#      'id': 'tr51',
#      'start': '19890226',
#      'successful': 59,
#      'therapy': 'Th19'},
#     {'condition': 'pc31',
#      'end': '19890414',
#      'id': 'tr52',
#      'start': '19890401',
#      'successful': 56,
#      'therapy': 'Th25'},
#     {'condition': 'pc31',
#      'end': '19890621',
#      'id': 'tr53',
#      'start': '19890512',
#      'successful': 100,
#      'therapy': 'Th23'}],
#    'type': 'Patient'},
#   {'age': 64,
#    'birthdate': '19570425',
#    'blood_group': 'O+',
#    'conditions': [],
#    'country_of_residence': 'Falkland Islands (Malvinas)',
#    'email': 'brandi64@yahoo.com',
#    'gender': 'male',
#    'id': 5,
#    'name': 'Frank Heavner',
#    'occupation': 'Exhibition designer',
#    'trials': [],
#    'type': 'Patient'},
#   {'age': 50,
#    'birthdate': '19710520',
#    'blood_group': 'O+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '19980519',
#      'id': 'pc32',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond248'},
#     {'cured': '19930811',
#      'diagnosed': '19921217',
#      'id': 'pc33',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond93'},
#     {'cured': '20080817',
#      'diagnosed': '20080309',
#      'id': 'pc34',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond302'},
#     {'cured': '19840803',
#      'diagnosed': '19840523',
#      'id': 'pc35',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond13'},
#     {'cured': '19740702',
#      'diagnosed': '19740512',
#      'id': 'pc36',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond234'}],
#    'country_of_residence': 'Bangladesh',
#    'email': 'amandaberg@yahoo.com',
#    'gender': 'male',
#    'id': 6,
#    'name': 'Wilson Yancey',
#    'occupation': 'Health promotion specialist',
#    'trials': [{'condition': 'pc32',
#      'end': '19980723',
#      'id': 'tr54',
#      'start': '19980701',
#      'successful': 23,
#      'therapy': 'Th13'},
#     {'condition': 'pc33',
#      'end': '19930321',
#      'id': 'tr55',
#      'start': '19930201',
#      'successful': 14,
#      'therapy': 'Th40'},
#     {'condition': 'pc33',
#      'end': '19930523',
#      'id': 'tr56',
#      'start': '19930410',
#      'successful': 59,
#      'therapy': 'Th3'},
#     {'condition': 'pc33',
#      'end': '19930717',
#      'id': 'tr57',
#      'start': '19930716',
#      'successful': 38,
#      'therapy': 'Th48'},
#     {'condition': 'pc33',
#      'end': '19930811',
#      'id': 'tr58',
#      'start': '19930729',
#      'successful': 100,
#      'therapy': 'Th10'},
#     {'condition': 'pc34',
#      'end': '20080501',
#      'id': 'tr59',
#      'start': '20080321',
#      'successful': 58,
#      'therapy': 'Th32'},
#     {'condition': 'pc34',
#      'end': '20080609',
#      'id': 'tr60',
#      'start': '20080519',
#      'successful': 65,
#      'therapy': 'Th18'},
#     {'condition': 'pc34',
#      'end': '20080817',
#      'id': 'tr61',
#      'start': '20080716',
#      'successful': 100,
#      'therapy': 'Th46'},
#     {'condition': 'pc35',
#      'end': '19840803',
#      'id': 'tr62',
#      'start': '19840617',
#      'successful': 100,
#      'therapy': 'Th29'},
#     {'condition': 'pc36',
#      'end': '19740702',
#      'id': 'tr63',
#      'start': '19740620',
#      'successful': 100,
#      'therapy': 'Th49'}],
#    'type': 'Patient'},
#   {'age': 62,
#    'birthdate': '19591123',
#    'blood_group': 'O+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '19970716',
#      'id': 'pc37',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond181'},
#     {'cured': '20121227',
#      'diagnosed': '20121109',
#      'id': 'pc38',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond15'},
#     {'cured': 'Null',
#      'diagnosed': '19890929',
#      'id': 'pc39',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond10'},
#     {'cured': 'Null',
#      'diagnosed': '19650608',
#      'id': 'pc40',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond109'},
#     {'cured': '19731125',
#      'diagnosed': '19731005',
#      'id': 'pc41',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond64'},
#     {'cured': '19700820',
#      'diagnosed': '19700603',
#      'id': 'pc42',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond148'}],
#    'country_of_residence': 'Egypt',
#    'email': 'grant88@hotmail.com',
#    'gender': 'male',
#    'id': 7,
#    'name': 'John Conger',
#    'occupation': 'Public relations officer',
#    'trials': [{'condition': 'pc38',
#      'end': '20121227',
#      'id': 'tr64',
#      'start': '20121213',
#      'successful': 100,
#      'therapy': 'Th37'},
#     {'condition': 'pc39',
#      'end': '19891202',
#      'id': 'tr65',
#      'start': '19891101',
#      'successful': 83,
#      'therapy': 'Th5'},
#     {'condition': 'pc40',
#      'end': '19650724',
#      'id': 'tr66',
#      'start': '19650718',
#      'successful': 43,
#      'therapy': 'Th35'},
#     {'condition': 'pc41',
#      'end': '19731125',
#      'id': 'tr67',
#      'start': '19731030',
#      'successful': 100,
#      'therapy': 'Th50'},
#     {'condition': 'pc42',
#      'end': '19700820',
#      'id': 'tr68',
#      'start': '19700717',
#      'successful': 100,
#      'therapy': 'Th17'}],
#    'type': 'Patient'},
#   {'age': 29,
#    'birthdate': '19921013',
#    'blood_group': 'B+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '20011124',
#      'id': 'pc43',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond222'},
#     {'cured': '19940908',
#      'diagnosed': '19940628',
#      'id': 'pc44',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond23'}],
#    'country_of_residence': 'United States Minor Outlying Islands',
#    'email': 'qrobinson@gmail.com',
#    'gender': 'male',
#    'id': 8,
#    'name': 'Jerry Taylor',
#    'occupation': 'Buyer, industrial',
#    'trials': [{'condition': 'pc44',
#      'end': '19940908',
#      'id': 'tr69',
#      'start': '19940722',
#      'successful': 100,
#      'therapy': 'Th31'}],
#    'type': 'Patient'},
#   {'age': 87,
#    'birthdate': '19340404',
#    'blood_group': 'O-',
#    'conditions': [{'cured': '19690219',
#      'diagnosed': '19681211',
#      'id': 'pc45',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond171'}],
#    'country_of_residence': 'Indonesia',
#    'email': 'dawn19@yahoo.com',
#    'gender': 'male',
#    'id': 9,
#    'name': 'Leroy Price',
#    'occupation': 'Magazine journalist',
#    'trials': [{'condition': 'pc45',
#      'end': '19690219',
#      'id': 'tr70',
#      'start': '19690209',
#      'successful': 100,
#      'therapy': 'Th47'}],
#    'type': 'Patient'},
#   {'age': 59,
#    'birthdate': '19620127',
#    'blood_group': 'O+',
#    'conditions': [{'cured': '20060130',
#      'diagnosed': '20050909',
#      'id': 'pc46',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond189'},
#     {'cured': '19790826',
#      'diagnosed': '19790103',
#      'id': 'pc47',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond223'},
#     {'cured': '20121210',
#      'diagnosed': '20120827',
# ...
#      'end': '19600721',
#      'id': 'tr9694',
#      'start': '19600703',
#      'successful': 3,
#      'therapy': 'Th1'},
#     {'condition': 'pc5438',
#      'end': '19600804',
#      'id': 'tr9695',
#      'start': '19600727',
#      'successful': 78,
#      'therapy': 'Th4'},
#     {'condition': 'pc5438',
#      'end': '19601011',
#      'id': 'tr9696',
#      'start': '19600918',
#      'successful': 3,
#      'therapy': 'Th18'},
#     {'condition': 'pc5438',
#      'end': '19601212',
#      'id': 'tr9697',
#      'start': '19601104',
#      'successful': 100,
#      'therapy': 'Th50'},
#     {'condition': 'pc5440',
#      'end': '20051108',
#      'id': 'tr9698',
#      'start': '20051018',
#      'successful': 74,
#      'therapy': 'Th48'},
#     {'condition': 'pc5440',
#      'end': '20060107',
#      'id': 'tr9699',
#      'start': '20051119',
#      'successful': 70,
#      'therapy': 'Th45'},
#     {'condition': 'pc5440',
#      'end': '20060312',
#      'id': 'tr9700',
#      'start': '20060217',
#      'successful': 100,
#      'therapy': 'Th41'},
#     {'condition': 'pc5441',
#      'end': '19800209',
#      'id': 'tr9701',
#      'start': '19800130',
#      'successful': 36,
#      'therapy': 'Th17'},
#     {'condition': 'pc5441',
#      'end': '19800425',
#      'id': 'tr9702',
#      'start': '19800309',
#      'successful': 52,
#      'therapy': 'Th37'},
#     {'condition': 'pc5441',
#      'end': '19800612',
#      'id': 'tr9703',
#      'start': '19800606',
#      'successful': 100,
#      'therapy': 'Th35'},
#     {'condition': 'pc5442',
#      'end': '19860717',
#      'id': 'tr9704',
#      'start': '19860714',
#      'successful': 27,
#      'therapy': 'Th50'},
#     {'condition': 'pc5442',
#      'end': '19860925',
#      'id': 'tr9705',
#      'start': '19860820',
#      'successful': 29,
#      'therapy': 'Th7'}],
#    'type': 'Patient'},
#   {'age': 51,
#    'birthdate': '19700707',
#    'blood_group': 'B-',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '20120103',
#      'id': 'pc5443',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond268'},
#     {'cured': 'Null',
#      'diagnosed': '19920721',
#      'id': 'pc5444',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond234'},
#     {'cured': '20150302',
#      'diagnosed': '20140721',
#      'id': 'pc5445',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond119'},
#     {'cured': '19761223',
#      'diagnosed': '19761007',
#      'id': 'pc5446',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond134'},
#     {'cured': '20150317',
#      'diagnosed': '20141128',
#      'id': 'pc5447',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond179'},
#     {'cured': '20141224',
#      'diagnosed': '20140913',
#      'id': 'pc5448',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond217'}],
#    'country_of_residence': 'Sweden',
#    'email': 'pattersonmichael@gmail.com',
#    'gender': 'female',
#    'id': 996,
#    'name': 'Katherine Moran',
#    'occupation': 'Commercial/residential surveyor',
#    'trials': [{'condition': 'pc5445',
#      'end': '20140915',
#      'id': 'tr9706',
#      'start': '20140809',
#      'successful': 36,
#      'therapy': 'Th10'},
#     {'condition': 'pc5445',
#      'end': '20141023',
#      'id': 'tr9707',
#      'start': '20141008',
#      'successful': 51,
#      'therapy': 'Th35'},
#     {'condition': 'pc5445',
#      'end': '20141225',
#      'id': 'tr9708',
#      'start': '20141217',
#      'successful': 33,
#      'therapy': 'Th11'},
#     {'condition': 'pc5445',
#      'end': '20150125',
#      'id': 'tr9709',
#      'start': '20141229',
#      'successful': 41,
#      'therapy': 'Th20'},
#     {'condition': 'pc5445',
#      'end': '20150302',
#      'id': 'tr9710',
#      'start': '20150205',
#      'successful': 100,
#      'therapy': 'Th44'},
#     {'condition': 'pc5446',
#      'end': '19761121',
#      'id': 'tr9711',
#      'start': '19761024',
#      'successful': 65,
#      'therapy': 'Th10'},
#     {'condition': 'pc5446',
#      'end': '19761223',
#      'id': 'tr9712',
#      'start': '19761203',
#      'successful': 100,
#      'therapy': 'Th23'},
#     {'condition': 'pc5447',
#      'end': '20150113',
#      'id': 'tr9713',
#      'start': '20150103',
#      'successful': 36,
#      'therapy': 'Th20'},
#     {'condition': 'pc5447',
#      'end': '20150209',
#      'id': 'tr9714',
#      'start': '20150202',
#      'successful': 77,
#      'therapy': 'Th21'},
#     {'condition': 'pc5447',
#      'end': '20150317',
#      'id': 'tr9715',
#      'start': '20150213',
#      'successful': 100,
#      'therapy': 'Th3'},
#     {'condition': 'pc5448',
#      'end': '20141107',
#      'id': 'tr9716',
#      'start': '20140925',
#      'successful': 20,
#      'therapy': 'Th34'},
#     {'condition': 'pc5448',
#      'end': '20141224',
#      'id': 'tr9717',
#      'start': '20141216',
#      'successful': 100,
#      'therapy': 'Th21'}],
#    'type': 'Patient'},
#   {'age': 41,
#    'birthdate': '19801002',
#    'blood_group': 'O+',
#    'conditions': [{'cured': '20120216',
#      'diagnosed': '20111012',
#      'id': 'pc5449',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond279'},
#     {'cured': 'Null',
#      'diagnosed': '20161108',
#      'id': 'pc5450',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond134'}],
#    'country_of_residence': 'Croatia',
#    'email': 'pallen@yahoo.com',
#    'gender': 'female',
#    'id': 997,
#    'name': 'Rachelle Santana',
#    'occupation': 'Commercial/residential surveyor',
#    'trials': [{'condition': 'pc5449',
#      'end': '20111104',
#      'id': 'tr9718',
#      'start': '20111029',
#      'successful': 36,
#      'therapy': 'Th1'},
#     {'condition': 'pc5449',
#      'end': '20111217',
#      'id': 'tr9719',
#      'start': '20111109',
#      'successful': 65,
#      'therapy': 'Th47'},
#     {'condition': 'pc5449',
#      'end': '20120216',
#      'id': 'tr9720',
#      'start': '20120114',
#      'successful': 100,
#      'therapy': 'Th20'},
#     {'condition': 'pc5450',
#      'end': '20161213',
#      'id': 'tr9721',
#      'start': '20161202',
#      'successful': 52,
#      'therapy': 'Th30'},
#     {'condition': 'pc5450',
#      'end': '20170201',
#      'id': 'tr9722',
#      'start': '20161224',
#      'successful': 65,
#      'therapy': 'Th4'},
#     {'condition': 'pc5450',
#      'end': '20170311',
#      'id': 'tr9723',
#      'start': '20170301',
#      'successful': 34,
#      'therapy': 'Th42'}],
#    'type': 'Patient'},
#   {'age': 97,
#    'birthdate': '19241115',
#    'blood_group': 'O+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '19751128',
#      'id': 'pc5451',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond2'},
#     {'cured': '20020805',
#      'diagnosed': '20020614',
#      'id': 'pc5452',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond83'},
#     {'cured': 'Null',
#      'diagnosed': '19500128',
#      'id': 'pc5453',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond269'},
#     {'cured': '19730301',
#      'diagnosed': '19730214',
#      'id': 'pc5454',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond276'},
#     {'cured': 'Null',
#      'diagnosed': '19870218',
#      'id': 'pc5455',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond320'},
#     {'cured': '19960129',
#      'diagnosed': '19951017',
#      'id': 'pc5456',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond290'},
#     {'cured': '19640702',
#      'diagnosed': '19640128',
#      'id': 'pc5457',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond140'},
#     {'cured': '19640811',
#      'diagnosed': '19631224',
#      'id': 'pc5458',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond86'},
#     {'cured': 'Null',
#      'diagnosed': '19880408',
#      'id': 'pc5459',
#      'isCured': False,
#      'isTreated': False,
#      'kind': 'Cond65'},
#     {'cured': '19730730',
#      'diagnosed': '19730518',
#      'id': 'pc5460',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond15'},
#     {'cured': '19270313',
#      'diagnosed': '19270121',
#      'id': 'pc5461',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond136'},
#     {'cured': '19870822',
#      'diagnosed': '19860604',
#      'id': 'pc5462',
#      'isCured': True,
#      'isTreated': False,
#      'kind': 'Cond95'}],
#    'country_of_residence': 'Macedonia',
#    'email': 'levi28@yahoo.com',
#    'gender': 'male',
#    'id': 998,
#    'name': 'James Phillips',
#    'occupation': 'Research officer, political party',
#    'trials': [{'condition': 'pc5451',
#      'end': '19751219',
#      'id': 'tr9724',
#      'start': '19751207',
#      'successful': 12,
#      'therapy': 'Th5'},
#     {'condition': 'pc5451',
#      'end': '19760227',
#      'id': 'tr9725',
#      'start': '19760113',
#      'successful': 42,
#      'therapy': 'Th9'},
#     {'condition': 'pc5451',
#      'end': '19760502',
#      'id': 'tr9726',
#      'start': '19760318',
#      'successful': 64,
#      'therapy': 'Th22'},
#     {'condition': 'pc5451',
#      'end': '19760621',
#      'id': 'tr9727',
#      'start': '19760604',
#      'successful': 1,
#      'therapy': 'Th42'},
#     {'condition': 'pc5452',
#      'end': '20020805',
#      'id': 'tr9728',
#      'start': '20020627',
#      'successful': 100,
#      'therapy': 'Th16'},
#     {'condition': 'pc5453',
#      'end': '19500328',
#      'id': 'tr9729',
#      'start': '19500309',
#      'successful': 2,
#      'therapy': 'Th40'},
#     {'condition': 'pc5454',
#      'end': '19730301',
#      'id': 'tr9730',
#      'start': '19730226',
#      'successful': 100,
#      'therapy': 'Th50'},
#     {'condition': 'pc5456',
#      'end': '19951213',
#      'id': 'tr9731',
#      'start': '19951206',
#      'successful': 19,
#      'therapy': 'Th25'},
#     {'condition': 'pc5456',
#      'end': '19960129',
#      'id': 'tr9732',
#      'start': '19951224',
#      'successful': 100,
#      'therapy': 'Th46'},
#     {'condition': 'pc5457',
#      'end': '19640327',
#      'id': 'tr9733',
#      'start': '19640212',
#      'successful': 47,
#      'therapy': 'Th18'},
#     {'condition': 'pc5457',
#      'end': '19640702',
#      'id': 'tr9734',
#      'start': '19640524',
#      'successful': 100,
#      'therapy': 'Th48'},
#     {'condition': 'pc5458',
#      'end': '19640305',
#      'id': 'tr9735',
#      'start': '19640216',
#      'successful': 75,
#      'therapy': 'Th6'},
#     {'condition': 'pc5458',
#      'end': '19640324',
#      'id': 'tr9736',
#      'start': '19640312',
#      'successful': 34,
#      'therapy': 'Th22'},
#     {'condition': 'pc5458',
#      'end': '19640605',
#      'id': 'tr9737',
#      'start': '19640523',
#      'successful': 85,
#      'therapy': 'Th33'},
#     {'condition': 'pc5458',
#      'end': '19640811',
#      'id': 'tr9738',
#      'start': '19640725',
#      'successful': 100,
#      'therapy': 'Th39'},
#     {'condition': 'pc5460',
#      'end': '19730730',
#      'id': 'tr9739',
#      'start': '19730610',
#      'successful': 100,
#      'therapy': 'Th28'},
#     {'condition': 'pc5461',
#      'end': '19270313',
#      'id': 'tr9740',
#      'start': '19270221',
#      'successful': 100,
#      'therapy': 'Th4'}],
#    'type': 'Patient'},
#   {'age': 43,
#    'birthdate': '19780116',
#    'blood_group': 'O+',
#    'conditions': [{'cured': 'Null',
#      'diagnosed': '19920521',
#      'id': 'pc5463',
#      'isCured': False,
#      'isTreated': True,
#      'kind': 'Cond96'},
#     {'cured': '20040318',
#      'diagnosed': '20040222',
#      'id': 'pc5464',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond229'},
#     {'cured': '20110416',
#      'diagnosed': '20110325',
#      'id': 'pc5465',
#      'isCured': True,
#      'isTreated': True,
#      'kind': 'Cond162'}],
#    'country_of_residence': 'Cambodia',
#    'email': 'matthew24@yahoo.com',
#    'gender': 'female',
#    'id': 999,
#    'name': 'Maria Castanon',
#    'occupation': 'Fashion designer',
#    'trials': [{'condition': 'pc5463',
#      'end': '19920728',
#      'id': 'tr9741',
#      'start': '19920715',
#      'successful': 87,
#      'therapy': 'Th48'},
#     {'condition': 'pc5463',
#      'end': '19921007',
#      'id': 'tr9742',
#      'start': '19920912',
#      'successful': 31,
#      'therapy': 'Th20'},
#     {'condition': 'pc5463',
#      'end': '19921120',
#      'id': 'tr9743',
#      'start': '19921024',
#      'successful': 8,
#      'therapy': 'Th25'},
#     {'condition': 'pc5463',
#      'end': '19930130',
#      'id': 'tr9744',
#      'start': '19930119',
#      'successful': 47,
#      'therapy': 'Th26'},
#     {'condition': 'pc5463',
#      'end': '19930412',
#      'id': 'tr9745',
#      'start': '19930316',
#      'successful': 46,
#      'therapy': 'Th7'},
#     {'condition': 'pc5463',
#      'end': '19930609',
#      'id': 'tr9746',
#      'start': '19930420',
#      'successful': 41,
#      'therapy': 'Th18'},
#     {'condition': 'pc5464',
#      'end': '20040318',
#      'id': 'tr9747',
#      'start': '20040302',
#      'successful': 100,
#      'therapy': 'Th30'},
#     {'condition': 'pc5465',
#      'end': '20110416',
#      'id': 'tr9748',
#      'start': '20110408',
#      'successful': 100,
#      'therapy': 'Th8'}],
#    'type': 'Patient'},
#   ...],
#  'Therapies': [{'id': 'Th1', 'name': 'abortive therapy', 'type': 'Physio'},
#   {'id': 'Th2', 'name': 'antibody therapy', 'type': 'Physio'},
#   {'id': 'Th3', 'name': 'aquarium therapy', 'type': 'Acid'},
#   {'id': 'Th4', 'name': 'aurotherapy', 'type': 'Sugar'},
#   {'id': 'Th5', 'name': 'cell transfer therapy', 'type': 'Physio'},
#   {'id': 'Th6', 'name': 'chrysotherapy', 'type': 'Sugar'},
#   {'id': 'Th7', 'name': 'consolidation therapy', 'type': 'Sugar'},
#   {'id': 'Th8', 'name': 'counseling', 'type': 'Acid'},
#   {'id': 'Th9', 'name': 'crystal therapy', 'type': 'Physio'},
#   {'id': 'Th10', 'name': 'curative therapy', 'type': 'Acid'},
#   {'id': 'Th11', 'name': 'definitive therapy', 'type': 'Sugar'},
#   {'id': 'Th12', 'name': 'dietary therapy', 'type': 'Acid'},
#   {'id': 'Th13', 'name': 'drug therapy', 'type': 'Sugar'},
#   {'id': 'Th14',
#    'name': 'electromagnetic therapy (alternative medicine)',
#    'type': 'Acid'},
#   {'id': 'Th15', 'name': 'equine therapy', 'type': 'Acid'},
#   {'id': 'Th16', 'name': 'estrogen replacement therapy', 'type': 'Physio'},
#   {'id': 'Th17', 'name': 'exercise therapy', 'type': 'Sugar'},
#   {'id': 'Th18', 'name': 'gold standard therapy', 'type': 'Physio'},
#   {'id': 'Th19', 'name': 'herbal therapy', 'type': 'Sugar'},
#   {'id': 'Th20', 'name': 'phytotherapy', 'type': 'Physio'},
#   {'id': 'Th21', 'name': 'hippotherapy', 'type': 'Acid'},
#   {'id': 'Th22', 'name': 'immunosuppressive therapy', 'type': 'Sugar'},
#   {'id': 'Th23', 'name': 'induction therapy', 'type': 'Physio'},
#   {'id': 'Th24', 'name': 'intravenous immunoglobulin', 'type': 'Acid'},
#   {'id': 'Th25', 'name': 'investigational therapy', 'type': 'Sugar'},
#   {'id': 'Th26', 'name': 'laser therapy', 'type': 'Physio'},
#   {'id': 'Th27', 'name': 'leech therapy', 'type': 'Acid'},
#   {'id': 'Th28', 'name': 'low level laser therapy', 'type': 'Physio'},
#   {'id': 'Th29', 'name': 'magnetic resonance therapy', 'type': 'Physio'},
#   {'id': 'Th30', 'name': 'medical nutrition therapy', 'type': 'Sugar'},
#   {'id': 'Th31', 'name': 'medical therapy', 'type': 'Acid'},
#   {'id': 'Th32', 'name': 'molecular chaperone therapy', 'type': 'Physio'},
#   {'id': 'Th33', 'name': 'monotherapy', 'type': 'Sugar'},
#   {'id': 'Th34', 'name': 'mud therapy', 'type': 'Sugar'},
#   {'id': 'Th35', 'name': 'neurologic music therapy', 'type': 'Physio'},
#   {'id': 'Th36', 'name': 'neutron therapy', 'type': 'Acid'},
#   {'id': 'Th37', 'name': 'phytotherapy', 'type': 'Physio'},
#   {'id': 'Th38', 'name': 'polytherapy', 'type': 'Sugar'},
#   {'id': 'Th39', 'name': 'preventive therapy', 'type': 'Physio'},
#   {'id': 'Th40', 'name': 'prophylactic therapy', 'type': 'Acid'},
#   {'id': 'Th41', 'name': 'protein therapy', 'type': 'Physio'},
#   {'id': 'Th42', 'name': 'rehydration therapy', 'type': 'Physio'},
#   {'id': 'Th43', 'name': 'respiratory therapy', 'type': 'Physio'},
#   {'id': 'Th44', 'name': 'sound therapy', 'type': 'Sugar'},
#   {'id': 'Th45', 'name': 'speech therapy', 'type': 'Sugar'},
#   {'id': 'Th46', 'name': 'stem cell therapy', 'type': 'Physio'},
#   {'id': 'Th47', 'name': 'stepdown therapy', 'type': 'Sugar'},
#   {'id': 'Th48', 'name': 'supportive therapy', 'type': 'Acid'},
#   {'id': 'Th49', 'name': 'systemic therapy', 'type': 'Sugar'},
#   {'id': 'Th50', 'name': 'Waon therapy', 'type': 'Sugar'},
#   {'id': 'Th51', 'name': 'water cure (therapy)', 'type': 'Acid'}]}

# %%
therapies=pd.DataFrame.from_dict(pd.json_normalize(dataset["Therapies"]), orient='columns')
therapies.columns=["therapy","name","type"]

# %%
df=pd.read_csv("Dataset/datamining_data.csv")
df["id"]=df.id.astype(int)

# %%
df.head()
# Out:
#    Unnamed: 0 condition       end id_x     start  successful therapy  \
# 0           0       pc3  20120109  tr1  20111219        86.0    Th49
# 1           1       pc3  20120217  tr2  20120203        10.0    Th45
# 2           2       pc3  20120404  tr3  20120330       100.0    Th45
# 3           3       pc4  19650727  tr4  19650714       100.0    Th17
# 4           4       pc5  19731019  tr5  19730919       100.0    Th47
#
#       cured  diagnosed  isCured  isTreated     kind  id
# 0  20120404   20111218     True       True  Cond240   0
# 1  20120404   20111218     True       True  Cond240   0
# 2  20120404   20111218     True       True  Cond240   0
# 3  19650727   19650601     True       True   Cond39   0
# 4  19731019   19730915     True       True  Cond309   0

# %%
#item-based

# %% [markdown]
# #### Id,kind,therapy and succesful columns are used for Item-Based the Collaborative Filtering method

# %%
data_p=df[["id","kind","therapy","successful"]]

# %%
data_p["id"] = data_p["id"].astype(str) + "-" + data_p["kind"]
# Out:
# <ipython-input-12-e0a7b7f9e045>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_p["id"] = data_p["id"].astype(str) + "-" + data_p["kind"]

# %%
data_p=data_p[["id","therapy","successful"]]

# %% [markdown]
# #### This is the final dataset that I used. Id represent patientID-CondID. After I create matrix, I will recommend new therapies based on patientID and condID

# %%
data_p.head()
# Out:
#           id therapy  successful
# 0  0-Cond240    Th49        86.0
# 1  0-Cond240    Th45        10.0
# 2  0-Cond240    Th45       100.0
# 3   0-Cond39    Th17       100.0
# 4  0-Cond309    Th47       100.0

# %% [markdown]
# #### I used normalized values of the succesful rate but I also tried with normal values, the rmse is the same.

# %%
def normalize(data):
    # compute mean rating for each user
    mean = data.groupby(by='id', as_index=False)['successful'].mean()
    norm_ratings = pd.merge(data, mean, suffixes=('','_mean'), on='id')
    
    # normalize each rating by substracting the mean rating of the corresponding user
    norm_ratings['norm_successful'] = norm_ratings['successful'] - norm_ratings['successful_mean']
    return mean.to_numpy()[:, 1], norm_ratings

# %%
mean, norm_ratings = normalize() 
# label_encoder object knows how to understand word labels.
label_encoder_therapy = preprocessing.LabelEncoder()

#get user mean index
mean_id=data_p.groupby(by='id', as_index=False)['successful'].mean()

# Encode labels in column 'species'.
norm_ratings['therapy']= label_encoder_therapy.fit_transform(norm_ratings['therapy'])

#norm_ratings=norm_ratings.sort_values("therapy",ascending=True)
norm_ratings=norm_ratings[["id","therapy","successful","norm_successful"]]
np_ratings = norm_ratings.to_numpy()
np_ratings
# Out:
# array([['0-Cond240', 43, 86.0, 20.66666666666667],
#        ['0-Cond240', 39, 10.0, -55.33333333333333],
#        ['0-Cond240', 39, 100.0, 34.66666666666667],
#        ...,
#        ['99999-Cond135', 10, 53.0, -31.33333333333333],
#        ['99999-Cond135', 49, 100.0, 15.666666666666671],
#        ['99999-Cond135', 49, 100.0, 15.666666666666671]], dtype=object)

# %%
norm_ratings
# Out:
#                     id  therapy  successful  norm_successful
# 0            0-Cond240       43        86.0        20.666667
# 1            0-Cond240       39        10.0       -55.333333
# 2            0-Cond240       39       100.0        34.666667
# 3             0-Cond39        8       100.0         0.000000
# 4            0-Cond309       41       100.0         0.000000
# ...                ...      ...         ...              ...
# 1027025  99999-Cond128       45       100.0        37.333333
# 1027026  99999-Cond280       20        20.0         0.000000
# 1027027  99999-Cond135       10        53.0       -31.333333
# 1027028  99999-Cond135       49       100.0        15.666667
# 1027029  99999-Cond135       49       100.0        15.666667
#
# [1027030 rows x 4 columns]

# %% [markdown]
# #### I created a item-user matrix

# %%
def rating_matrix(dataframe, column):
    crosstab = pd.crosstab(dataframe.therapy, dataframe.id, dataframe[f'{column}'], aggfunc=sum).fillna(0).values
    matrix = csr_matrix(crosstab)
    return matrix

# %%
R = rating_matrix(norm_ratings,"norm_successful")

# %% [markdown]
# #### The shape of the matrix is 51x428290
# - 51 is the number of therapy

# %%
R
# Out:
# <51x428290 sparse matrix of type '<class 'numpy.float64'>'
# 	with 718261 stored elements in Compressed Sparse Row format>

# %%
def create_model(rating_matrix, metric):
    """
    - create the nearest neighbors model with the corresponding similarity metric
    - fit the model
    """
    model = NearestNeighbors(metric=metric, n_neighbors=21, algorithm='brute')
    model.fit(rating_matrix)    
    return model
def nearest_neighbors(rating_matrix, model):
    """    
    :param rating_matrix : rating matrix of shape (nb_patient, nb_therapy)
    :param model : nearest neighbors model    
    :return
        - similarities : distances of the neighbors from the referenced patient
        - neighbors : neighbors of the referenced patient in decreasing order of similarities
    """    
    similarities, neighbors = model.kneighbors(rating_matrix)        
    return similarities[:, 1:], neighbors[:, 1:]

# %%
model = create_model(R, metric="cosine")
similarities, neighbors = nearest_neighbors(R, model)

# %%
similarities.shape
# Out:
# (51, 20)

# %%
neighbors.shape
# Out:
# (51, 20)

# %%
np_ratings
# Out:
# array([['0-Cond240', 43, 86.0, 20.66666666666667],
#        ['0-Cond240', 39, 10.0, -55.33333333333333],
#        ['0-Cond240', 39, 100.0, 34.66666666666667],
#        ...,
#        ['99999-Cond135', 10, 53.0, -31.33333333333333],
#        ['99999-Cond135', 49, 100.0, 15.666666666666671],
#        ['99999-Cond135', 49, 100.0, 15.666666666666671]], dtype=object)

# %%
similarities
# Out:
# array([[1.01571502, 1.01652327, 1.01754691, ..., 1.01927691, 1.01950254,
#         1.01952189],
#        [1.01555523, 1.01572963, 1.01617772, ..., 1.01924582, 1.01924653,
#         1.01936117],
#        [1.01551277, 1.01613496, 1.01688833, ..., 1.01907864, 1.01908559,
#         1.01931387],
#        ...,
#        [1.01478213, 1.01602762, 1.01660466, ..., 1.01923587, 1.01939664,
#         1.01968146],
#        [1.01644173, 1.01656456, 1.01660466, ..., 1.0192936 , 1.01946946,
#         1.01960036],
#        [1.01654793, 1.01656456, 1.01665089, ..., 1.01934832, 1.01935396,
#         1.01965638]])

# %%
def candidate_items(userid):
    """
    :param userid : user id for which we wish to find candidate items    
    :return : I_u, candidates
    """
    
    # 1. Finding the set I_u of therapy already rated by patient userid
    I_u = np_ratings[np_ratings[:, 0] == userid]
    I_u = I_u[:, 1]
    
    # 2. Taking the union of similar therapy for all therapies in I_u to form the set of candidate therapies
    c = set()
        
    for iid in I_u:    
        # add the neighbors of therapy iid in the set of candidate therapies
        c.update(neighbors[int(iid)])
        
    c = list(c)
    # 3. exclude from the set C all therapies in I_u.
    candidates = np.setdiff1d(c, I_u, assume_unique=True)
    
    return I_u, candidates

# %%
test_user='6-Cond248'
i_u, u_candidates = candidate_items(test_user)
print('number of therapy for the patient  : ', len(i_u))
print('number of candidate therapy for the patient : ', len(u_candidates))
# Out:
# number of therapy for the patient  :  1
# number of candidate therapy for the patient :  20

# %%
def similarity_with_Iu(c, I_u):
    """
    compute similarity between an therapy c and a set of therapy I_u. For each therapy i in I_u, get similarity between 
    i and c, if c exists in the set of therapy similar to itemid.    
    :param c : itemid of a candidate therapy
    :param I_u : set of therapies already purchased by a given user    
    :return w : similarity between c and I_u
    """
    w = 0    
    for iid in I_u :        
        # get similarity between itemid and c, if c is one of the k nearest neighbors of itemid
        if c in neighbors[int(iid)] :
            w = w + similarities[int(iid), neighbors[int(iid)] == c][0]    
    return w

# %%
def rank_candidates(candidates, I_u):
    """
    rank candidate therapies according to their similarities with i_u    
    :param candidates : list of candidate items
    :param I_u : list of items purchased by the user    
    :return ranked_candidates : dataframe of candidate therapies, ranked in descending order of similarities with I_u
    """
    
    # list of candidate items mapped to their corresponding similarities to I_u
    sims = [similarity_with_Iu(c, I_u) for c in candidates]
    #candidates = label_encoder.inverse_transform(candidates)    
    mapping = list(zip(candidates, sims))
    
    ranked_candidates = sorted(mapping, key=lambda couple:couple[1], reverse=True)    
    return ranked_candidates

# %%
def topn_recommendation(userid, N=10):
    """
    Produce top-N recommendation for a given patient    
    :param userid : user for which we produce top-N recommendation
    :param n : length of the top-N recommendation list    
    :return topn
    """
    # find candidate therapy
    I_u, candidates = candidate_items(userid)
    
    # rank candidate items according to their similarities with I_u
    ranked_candidates = rank_candidates(candidates, I_u)
    
    # get the first N row of ranked_candidates to build the top N recommendation list
    topn = pd.DataFrame(ranked_candidates[:N], columns=['therapy','similarity_with_Iu'])    
    #topn = pd.merge(topn, data_p, on='CT', how='inner')    
    return topn

# %%
#This dataframe represents the top N recommendation list a user. These therapies are sorted in decreasing order of similarities with .
topn_recommendation(test_user)
# Out:
#    therapy  similarity_with_Iu
# 0       33            1.019669
# 1       16            1.019329
# 2       22            1.019266
# 3       41            1.019070
# 4       43            1.018984
# 5       10            1.018954
# 6       37            1.018843
# 7        5            1.018838
# 8       31            1.018631
# 9       39            1.018460

# %%
def predict(userid, itemid,mean_id):
    """
    Make rating prediction for user userid on therapy itemid    
    :param userid : id of the active patient
    :param itemid : id of the therapy for which we are making prediction        
    :return r_hat : predicted rating
    """
    
    # Get items similar to therapy itemid with their corresponding similarities
    item_neighbors = neighbors[int(itemid)]
    item_similarities = similarities[int(itemid)]

    # get ratings of user with id userid
    uratings = np_ratings[np_ratings[:, 0] == userid]
    
    # similar therapies rated by therapy the user of i
    siru = uratings[np.isin(uratings[:, 1], item_neighbors)]
    scores = siru[:, 2]
    indexes = [np.where(item_neighbors == iid)[0][0] for iid in siru[:,1]]    
    sims = item_similarities[indexes]
    
    dot = np.dot(scores, sims)
    som = np.sum(np.abs(sims))
    
    user_index=mean_id[mean_id["id"]==userid].index.values[0]

    if dot == 0 or som == 0:
        return mean[user_index]
    
    return dot / som

# %%
def topn_prediction(userid,mean_id):
    """
    :param userid : id of the active patient    
    :return topn : initial topN recommendations returned by the function item2item_topN
    :return topn_predict : topN recommendations reordered according to rating predictions
    """
    # make top N recommendation for the active user
    topn = topn_recommendation(userid)
    
    # get list of therapies of the top N list
    itemids = topn.therapy.to_list()
    
    predictions = []
    
    # make prediction for each therapies in the top N list
    for itemid in itemids:
        r = predict(userid, itemid,mean_id)
        
        predictions.append((itemid,r))
    
    predictions = pd.DataFrame(predictions, columns=['therapy','prediction'])
    
    # merge the predictions to topN_list and rearrange the list according to predictions
    topn_predict = pd.merge(topn, predictions, on='therapy', how='inner')
    topn_predict = topn_predict.sort_values(by=['similarity_with_Iu'], ascending=False)
    topn_predict["therapy"]=label_encoder_therapy.inverse_transform(topn_predict["therapy"])    
    
    
    return topn, topn_predict

# %%
topn, topn_predict = topn_prediction(userid='6-Cond248',mean_id=mean_id)
topn_predict
# Out:
#   therapy  similarity_with_Iu  prediction
# 0     Th4            1.019669        23.0
# 1    Th24            1.019329        23.0
# 2     Th3            1.019266        23.0
# 3    Th47            1.019070        23.0
# 4    Th49            1.018984        23.0
# 5    Th19            1.018954        23.0
# 6    Th43            1.018843        23.0
# 7    Th14            1.018838        23.0
# 8    Th38            1.018631        23.0
# 9    Th45            1.018460        23.0

# %% [markdown]
# ### Test

# %% [markdown]
# #### For the last part of the code, I predicted a recommadation for the test dataset, but for the condition "pc277636" does not exist in my dataset so I couldn't find a recommadation for this patient and condition.

# %%
test_data=pd.read_csv('datasetB_cases.txt', delimiter = "\t")
test_data=test_data.reset_index()
test_data["PatientID"]=test_data["index"]
test_data.drop("index",inplace=True,axis=1)
test_data.columns=["id","condition"]
test_data=test_data.merge(df[["id","condition","kind"]],on=["id","condition"],how="left").drop_duplicates()
test_data["id"]=test_data["id"].astype(str)+"-"+test_data["kind"]
test_data.fillna("9999999-Cond99999",inplace=True)
test_list=test_data["id"].to_list()

# %%
test_data.head()
# Out:
#                    id condition               kind
# 0           6-Cond248      pc32            Cond248
# 1   9999999-Cond99999  pc277636  9999999-Cond99999
# 2        82486-Cond16  pc445475             Cond16
# 9       51348-Cond216  pc277652            Cond216
# 14      51358-Cond120  pc277696            Cond120

# %%
def test(test_list):

  patient=[]
  condition=[]
  prediction_therapy=[]
  prediction_name=[]

  for i in test_list:
      topn, topn_predict = topn_prediction(userid=i)
      pred=pd.merge(topn_predict,therapies,on="therapy",how="left")[["therapy","name"]]
      patient.append(i.split("-")[0])
      condition.append(i.split("-")[1])
      prediction_therapy.append(pred["therapy"].to_list())
      prediction_name.append(pred["name"].to_list())
  pred=pd.DataFrame([patient,condition,prediction_therapy,prediction_name]).T
  pred.columns=["PatientId","condition","Recommended_Therapy","Recommended_Therapy_name"]
  results=pred.to_dict('records')

  with io.open('test_results.txt', 'w', encoding='utf-8') as f:
    f.write(json.dumps(results, ensure_ascii=False))

  return results

# %%
test(test_list)
# Out:
# [{'PatientId': '6',
#   'condition': 'Cond248',
#   'Recommended_Therapy': ['Th4',
#    'Th24',
#    'Th3',
#    'Th47',
#    'Th49',
#    'Th19',
#    'Th43',
#    'Th14',
#    'Th38',
#    'Th45'],
#   'Recommended_Therapy_name': ['aurotherapy',
#    'intravenous immunoglobulin',
#    'aquarium therapy',
#    'stepdown therapy',
#    'systemic therapy',
#    'herbal therapy',
#    'respiratory therapy',
#    'electromagnetic therapy (alternative medicine)',
#    'polytherapy',
#    'speech therapy']},
#  {'PatientId': '9999999',
#   'condition': 'Cond99999',
#   'Recommended_Therapy': [],
#   'Recommended_Therapy_name': []},
#  {'PatientId': '82486',
#   'condition': 'Cond16',
#   'Recommended_Therapy': ['Th17',
#    'Th13',
#    'Th12',
#    'Th10',
#    'Th8',
#    'Th18',
#    'Th7',
#    'Th29',
#    'Th25',
#    'Th40'],
#   'Recommended_Therapy_name': ['exercise therapy',
#    'drug therapy',
#    'dietary therapy',
#    'curative therapy',
#    'counseling',
#    'gold standard therapy',
#    'consolidation therapy',
#    'magnetic resonance therapy',
#    'investigational therapy',
#    'prophylactic therapy']},
#  {'PatientId': '51348',
#   'condition': 'Cond216',
#   'Recommended_Therapy': ['Th14',
#    'Th16',
#    'Th5',
#    'Th11',
#    'Th37',
#    'Th40',
#    'Th9',
#    'Th21',
#    'Th34',
#    'Th48'],
#   'Recommended_Therapy_name': ['electromagnetic therapy (alternative medicine)',
#    'estrogen replacement therapy',
#    'cell transfer therapy',
#    'definitive therapy',
#    'phytotherapy',
#    'prophylactic therapy',
#    'crystal therapy',
#    'hippotherapy',
#    'mud therapy',
#    'supportive therapy']},
#  {'PatientId': '51358',
#   'condition': 'Cond120',
#   'Recommended_Therapy': ['Th17',
#    'Th35',
#    'Th25',
#    'Th7',
#    'Th1',
#    'Th30',
#    'Th49',
#    'Th12',
#    'Th40',
#    'Th4'],
#   'Recommended_Therapy_name': ['exercise therapy',
#    'neurologic music therapy',
#    'investigational therapy',
#    'consolidation therapy',
#    'abortive therapy',
#    'medical nutrition therapy',
#    'systemic therapy',
#    'dietary therapy',
#    'prophylactic therapy',
#    'aurotherapy']},
#  {'PatientId': '51362',
#   'condition': 'Cond316',
#   'Recommended_Therapy': ['Th23',
#    'Th49',
#    'Th34',
#    'Th20',
#    'Th14',
#    'Th16',
#    'Th44',
#    'Th27',
#    'Th31',
#    'Th46'],
#   'Recommended_Therapy_name': ['induction therapy',
#    'systemic therapy',
#    'mud therapy',
#    'phytotherapy',
#    'electromagnetic therapy (alternative medicine)',
#    'estrogen replacement therapy',
#    'sound therapy',
#    'leech therapy',
#    'medical therapy',
#    'stem cell therapy']},
#  {'PatientId': '51366',
#   'condition': 'Cond322',
#   'Recommended_Therapy': ['Th7',
#    'Th2',
#    'Th24',
#    'Th31',
#    'Th4',
#    'Th27',
#    'Th34',
#    'Th30',
#    'Th25',
#    'Th15'],
#   'Recommended_Therapy_name': ['consolidation therapy',
#    'antibody therapy',
#    'intravenous immunoglobulin',
#    'medical therapy',
#    'aurotherapy',
#    'leech therapy',
#    'mud therapy',
#    'medical nutrition therapy',
#    'investigational therapy',
#    'equine therapy']},
#  {'PatientId': '51387',
#   'condition': 'Cond103',
#   'Recommended_Therapy': ['Th27',
#    'Th46',
#    'Th45',
#    'Th44',
#    'Th14',
#    'Th15',
#    'Th26',
#    'Th23',
#    'Th21',
#    'Th20'],
#   'Recommended_Therapy_name': ['leech therapy',
#    'stem cell therapy',
#    'speech therapy',
#    'sound therapy',
#    'electromagnetic therapy (alternative medicine)',
#    'equine therapy',
#    'laser therapy',
#    'induction therapy',
#    'hippotherapy',
#    'phytotherapy']},
#  {'PatientId': '51416',
#   'condition': 'Cond12',
#   'Recommended_Therapy': ['Th34',
#    'Th49',
#    'Th1',
#    'Th27',
#    'Th10',
#    'Th20',
#    'Th47',
#    'Th51',
#    'Th29',
#    'Th41'],
#   'Recommended_Therapy_name': ['mud therapy',
#    'systemic therapy',
#    'abortive therapy',
#    'leech therapy',
#    'curative therapy',
#    'phytotherapy',
#    'stepdown therapy',
#    'water cure (therapy)',
#    'magnetic resonance therapy',
#    'protein therapy']},
#  {'PatientId': '51453',
#   'condition': 'Cond176',
#   'Recommended_Therapy': ['Th12',
#    'Th1',
#    'Th46',
#    'Th15',
#    'Th5',
#    'Th50',
#    'Th34',
#    'Th17',
#    'Th35',
#    'Th25'],
#   'Recommended_Therapy_name': ['dietary therapy',
#    'abortive therapy',
#    'stem cell therapy',
#    'equine therapy',
#    'cell transfer therapy',
#    'Waon therapy',
#    'mud therapy',
#    'exercise therapy',
#    'neurologic music therapy',
#    'investigational therapy']}]

# %% [markdown]
# ### Evaluate the RMSE

# %%
def get_examples(dataframe, labels_column="successful"):
    examples = dataframe[['id', 'therapy']].values
    labels = dataframe[f'{labels_column}'].values
    return examples, labels

# %%
def train_test_split(examples, labels, test_size=0.1, verbose=0):
    if verbose:
        print("Train/Test split ")
        print(100-test_size*100, "% of training data")
        print(test_size*100, "% of testing data")    

    # split data into train and test sets
    train_examples, test_examples, train_labels, test_labels = sklearn_train_test_split(
        examples, 
        labels, 
        test_size=0.04, 
        random_state=42, 
        shuffle=True
    )

    # transform train and test examples to their corresponding one-hot representations
    train_users = train_examples[:, 0]
    test_users = test_examples[:, 0]

    train_items = train_examples[:, 1]
    test_items = test_examples[:, 1]

    # Final training and test set
    x_train = np.array(list(zip(train_users, train_items)))
    x_test = np.array(list(zip(test_users, test_items)))

    y_train = train_labels
    y_test = test_labels

    if verbose:
        print()
        print('number of training examples : ', x_train.shape)
        print('number of training labels : ', y_train.shape)
        print('number of test examples : ', x_test.shape)
        print('number of test labels : ', y_test.shape)

    return (x_train, x_test), (y_train, y_test)

# %%
# get examples as tuples of userids and itemids and labels from normalize ratings
raw_examples, raw_labels = get_examples(norm_ratings, labels_column='successful')
# train test split
(x_train, x_test), (y_train, y_test) = train_test_split(examples=raw_examples, labels=raw_labels)

# %%
def evaluate(x_test, y_test):
        print('Evaluate the model on {} test data ...'.format(x_test.shape[0]))
        preds = list(predict(u, int(i),mean_id) for (u, i) in x_test)
        rmse = sqrt(mean_squared_error(y_test,np.array(preds)))
        print('\nRMAE :', rmse)
        return rmse

# %%
evaluate(x_test, y_test)
# Out:
# Evaluate the model on 41082 test data ...
#
# RMAE : 36.383018520024336
# 36.383018520024336

# %% [markdown]
# ## Experiment 2 patients  selected who had at least one trial for same condition and whose most recent trial had ended with a higher succesful rate

# %%
data_p.head()
# Out:
#           id therapy  successful
# 0  0-Cond240    Th49        86.0
# 1  0-Cond240    Th45        10.0
# 2  0-Cond240    Th45       100.0
# 3   0-Cond39    Th17       100.0
# 4  0-Cond309    Th47       100.0

# %%
data_exp=data_p["id"]+","+data_p["therapy"]
data_exp=pd.DataFrame(data_exp)
data_exp["successful"]=data_p["successful"]
data_exp.columns=["id","successful"]
data_exp_1=pd.DataFrame(data_exp.groupby("id").successful.max()).reset_index()
dt=data_exp_1["id"].str.split(",", n = 1, expand = True)
dt["successful"]=data_exp_1["successful"]
dt.columns=["id","therapy","successful"]

# %%
dt
# Out:
#                    id therapy  successful
# 0           0-Cond240    Th45       100.0
# 1           0-Cond240    Th49        86.0
# 2           0-Cond280    Th19        59.0
# 3           0-Cond280    Th29        56.0
# 4           0-Cond280     Th3        30.0
# ...               ...     ...         ...
# 918298  99999-Cond280    Th28        20.0
# 918299  99999-Cond319     Th6       100.0
# 918300    99999-Cond5     Th6       100.0
# 918301   99999-Cond51    Th11       100.0
# 918302    99999-Cond7    Th13       100.0
#
# [918303 rows x 3 columns]

# %%
mean, norm_ratings = normalize(dt) 
# label_encoder object knows how to understand word labels.
label_encoder_therapy = preprocessing.LabelEncoder()

#get user mean index
mean_id=dt.groupby(by='id', as_index=False)['successful'].mean()

# Encode labels in column 'species'.
norm_ratings['therapy']= label_encoder_therapy.fit_transform(norm_ratings['therapy'])

#norm_ratings=norm_ratings.sort_values("therapy",ascending=True)
norm_ratings=norm_ratings[["id","therapy","successful","norm_successful"]]
np_ratings = norm_ratings.to_numpy()
np_ratings
# Out:
# array([['0-Cond240', 39, 100.0, 7.0],
#        ['0-Cond240', 43, 86.0, -7.0],
#        ['0-Cond280', 10, 59.0, 6.0],
#        ...,
#        ['99999-Cond5', 47, 100.0, 0.0],
#        ['99999-Cond51', 2, 100.0, 0.0],
#        ['99999-Cond7', 4, 100.0, 0.0]], dtype=object)

# %%
R = rating_matrix(norm_ratings,"successful")

# %%
model = create_model(R, metric="cosine")
similarities, neighbors = nearest_neighbors(R, model)

# %%
# get examples as tuples of userids and itemids and labels from normalize ratings
raw_examples, raw_labels = get_examples(norm_ratings, labels_column='norm_successful')
# train test split
(x_train, x_test), (y_train, y_test) = train_test_split(examples=raw_examples, labels=raw_labels)

# %%
evaluate(x_test, y_test)
# Out:
# Evaluate the model on 36733 test data ...
#
# RMAE : 80.35910075641252
# 80.35910075641252
